# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\nickm\OneDrive\Documents\GitHub\dsc520\data\insurance_claims.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
df.cov()
# Out:
#                              months_as_customer            age  policy_number  \
# months_as_customer                 1.325104e+04     970.201810   1.703130e+06
# age                                9.702018e+02      83.544841   1.395997e+05
# policy_number                      1.703130e+06  139599.665361   6.608139e+10
# policy_deductable                  1.888144e+03     163.235235  -1.059731e+06
# policy_annual_premium              1.410315e+02      32.145675   1.416366e+06
# umbrella_limit                     4.098745e+06  380632.632633   5.296036e+09
# insured_zip                        1.476998e+05   16780.292669   1.305565e+08
# capital-gains                      2.053193e+04   -1802.445245   7.023384e+07
# capital-loss                       6.537987e+04    1892.620220  -4.095652e+07
# incident_hour_of_the_day           5.652515e+01       5.538026   2.013220e+02
# number_of_vehicles_involved        1.728322e+00       0.205834   3.518009e+03
# ...

# %% [markdown]
# # Pre Processing

# %%
df= df.replace('?', np.NaN)

# %%
df.isnull().any()
# Out:
# months_as_customer             False
# age                            False
# policy_number                  False
# policy_bind_date               False
# policy_state                   False
# policy_csl                     False
# policy_deductable              False
# policy_annual_premium          False
# umbrella_limit                 False
# insured_zip                    False
# insured_sex                    False
# insured_education_level        False
# insured_occupation             False
# insured_hobbies                False
# insured_relationship           False
# capital-gains                  False
# capital-loss                   False
# incident_date                  False
# incident_type                  False
# collision_type                  True
# incident_severity              False
# authorities_contacted          False
# incident_state                 False
# incident_city                  False
# incident_location              False
# ...

# %%
df.collision_type.value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %%
df.collision_type.head(15)
# Out:
# 0      Side Collision
# 1                 NaN
# 2      Rear Collision
# 3     Front Collision
# 4                 NaN
# 5      Rear Collision
# 6     Front Collision
# 7     Front Collision
# 8     Front Collision
# 9      Rear Collision
# 10    Front Collision
# 11    Front Collision
# 12     Rear Collision
# 13                NaN
# 14     Rear Collision
# Name: collision_type, dtype: object

# %%
df['collision_type'].fillna(df['collision_type'].mode()[0], inplace = True)

# %%
df.collision_type.value_counts()
# Out:
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %%
df['property_damage'].fillna('NO', inplace = True)

# %%
df['police_report_available'].fillna('NO', inplace = True)

# %%
df.isnull().any()
# Out:
# months_as_customer             False
# age                            False
# policy_number                  False
# policy_bind_date               False
# policy_state                   False
# policy_csl                     False
# policy_deductable              False
# policy_annual_premium          False
# umbrella_limit                 False
# insured_zip                    False
# insured_sex                    False
# insured_education_level        False
# insured_occupation             False
# insured_hobbies                False
# insured_relationship           False
# capital-gains                  False
# capital-loss                   False
# incident_date                  False
# incident_type                  False
# collision_type                 False
# incident_severity              False
# authorities_contacted          False
# incident_state                 False
# incident_city                  False
# incident_location              False
# ...

# %%
df['fraud_reported'] = df['fraud_reported'].replace(('Y','N'),(1,0))

# %%
df.fraud_reported.value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# capital-gains                          0.006399 -0.007075       0.009802
# capital-loss                           0.020209  0.007368      -0.005669
# incident_hour_of_the_day               0.070639  0.087161       0.000113
# number_of_vehicles_involved            0.014736  0.022102       0.013432
# bodily_injuries                       -0.010162 -0.015679      -0.004558
# ...

# %%
# set up the figure size
plt.rcParams['figure.figsize'] = (12, 10)

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       10/17/2014           OH
# 1                 228   42         342868        6/27/2006           IN
# 2                 134   29         687698         9/6/2000           OH
# 3                 256   41         227811        5/25/1990           IL
# 4                 228   44         367455         6/6/2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# ...

# %%
df.insured_sex.value_counts()
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %%
df['insured_sex'] = df['insured_sex'].replace(('MALE','FEMALE'),(0,1))

# %%
df.insured_sex.value_counts()
# Out:
# 1    537
# 0    463
# Name: insured_sex, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()

# %%
df.insured_education_level.value_counts()
# Out:
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %%
df['insured_education_level']= labelencoder.fit_transform(df['insured_education_level'])

# %%
df.insured_education_level.value_counts()
# Out:
# 3    161
# 2    160
# 0    145
# 4    144
# 5    143
# 6    125
# 1    122
# Name: insured_education_level, dtype: int64

# %%
df.incident_type.value_counts()
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %%
df['incident_type']= labelencoder.fit_transform(df['incident_type'])

# %%
df.incident_type.value_counts()
# Out:
# 0    419
# 2    403
# 3     94
# 1     84
# Name: incident_type, dtype: int64

# %%
df.incident_severity.value_counts()
# Out:
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64

# %%
df['incident_severity']= labelencoder.fit_transform(df['incident_severity'])

# %%
df.incident_severity.value_counts()
# Out:
# 1    354
# 2    280
# 0    276
# 3     90
# Name: incident_severity, dtype: int64

# %%
df.collision_type.value_counts()
# Out:
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64

# %%
df['collision_type']= labelencoder.fit_transform(df['collision_type'])

# %%
df.collision_type.value_counts()
# Out:
# 1    470
# 2    276
# 0    254
# Name: collision_type, dtype: int64

# %%
df.authorities_contacted.value_counts()
# Out:
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %%
df['authorities_contacted']= labelencoder.fit_transform(df['authorities_contacted'])

# %%
df.authorities_contacted.value_counts()
# Out:
# 4    292
# 1    223
# 3    198
# 0    196
# 2     91
# Name: authorities_contacted, dtype: int64

# %%
df.property_damage.value_counts()
# Out:
# NO     698
# YES    302
# Name: property_damage, dtype: int64

# %%
df['property_damage'] = df['property_damage'].replace(('YES','NO'),(1,0))

# %%
df.property_damage.value_counts()
# Out:
# 0    698
# 1    302
# Name: property_damage, dtype: int64

# %%
df.police_report_available.value_counts()
# Out:
# NO     686
# YES    314
# Name: police_report_available, dtype: int64

# %%
df['police_report_available'] = df['police_report_available'].replace(('YES','NO'),(1,0))

# %%
df.police_report_available.value_counts()
# Out:
# 0    686
# 1    314
# Name: police_report_available, dtype: int64

# %%
df.auto_make.value_counts()
# Out:
# Dodge         80
# Suburu        80
# Saab          80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64

# %%
df['auto_make']= labelencoder.fit_transform(df['auto_make'])

# %%
df.auto_make.value_counts()
# Out:
# 11    80
# 10    80
# 4     80
# 9     78
# 3     76
# 5     72
# 2     72
# 12    70
# 1     69
# 13    68
# 0     68
# 7     67
# 8     65
# 6     55
# Name: auto_make, dtype: int64

# %%
df.policy_state.value_counts()
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %%
df['policy_state']= labelencoder.fit_transform(df['policy_state'])

# %%
df.policy_state.value_counts()
# Out:
# 2    352
# 0    338
# 1    310
# Name: policy_state, dtype: int64

# %%
df.incident_city.value_counts()
# Out:
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %%
df['incident_city']= labelencoder.fit_transform(df['incident_city'])

# %%
df.incident_city.value_counts()
# Out:
# 6    157
# 0    152
# 1    149
# 3    145
# 2    141
# 5    134
# 4    122
# Name: incident_city, dtype: int64

# %%
df.insured_occupation.value_counts()
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
df['insured_occupation']= labelencoder.fit_transform(df['insured_occupation'])

# %%
df.insured_occupation.value_counts()
# Out:
# 6     93
# 9     85
# 12    78
# 11    76
# 3     76
# 2     74
# 13    72
# 8     71
# 7     71
# 1     69
# 0     65
# 10    63
# 5     54
# 4     53
# Name: insured_occupation, dtype: int64

# %%
df.incident_state.value_counts()
# Out:
# NY    262
# SC    248
# WV    217
# NC    110
# VA    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %%
df['incident_state']= labelencoder.fit_transform(df['incident_state'])

# %%
df.incident_state.value_counts()
# Out:
# 1    262
# 4    248
# 6    217
# 5    110
# 0    110
# 3     30
# 2     23
# Name: incident_state, dtype: int64

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922098       0.057555
# age                                    0.922098  1.000000       0.059413
# policy_number                          0.057555  0.059413       1.000000
# policy_state                          -0.000328 -0.014533       0.072815
# policy_deductable                      0.026807  0.029188      -0.006738
# policy_annual_premium                  0.005018  0.014404       0.022566
# umbrella_limit                         0.015498  0.018126       0.008968
# insured_zip                            0.017895  0.025604       0.007083
# insured_sex                           -0.060925 -0.073337      -0.004564
# insured_education_level               -0.000833  0.000969      -0.037264
# insured_occupation                     0.009814  0.017220      -0.014422
# capital-gains                          0.006399 -0.007075       0.009802
# ...

# %%
test_data = df.drop(['months_as_customer', 'policy_number', '_c39', 'policy_bind_date', 'policy_csl','insured_hobbies','insured_relationship', 'incident_date','incident_location','auto_model' ],  axis = 1)

# %%
test_data.head()
# Out:
#    age  policy_state  policy_deductable  policy_annual_premium  \
# 0   48             2               1000                1406.91
# 1   42             1               2000                1197.22
# 2   29             2               2000                1413.14
# 3   41             0               2000                1415.74
# 4   44             0               1000                1583.91
#
#    umbrella_limit  insured_zip  insured_sex  insured_education_level  \
# 0               0       466132            0                        4
# 1         5000000       468176            0                        4
# 2         5000000       430632            1                        6
# 3         6000000       608117            1                        6
# 4         6000000       610706            0                        0
#
#    insured_occupation  capital-gains  capital-loss  incident_type  \
# 0                   2          53300             0              2
# ...

# %%
x = test_data.drop(['fraud_reported'], axis = 1)

# %%
y = test_data['fraud_reported']

# %%
from sklearn.model_selection import train_test_split

# split the data
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size =0.3, random_state=15)

# %%
# number of samples in each set
print("No. of samples in training set: ", X_train.shape[0])
print("No. of samples in validation set:", X_val.shape[0])
# Out:
# No. of samples in training set:  700
# No. of samples in validation set: 300

# %%
# Dems and Rep
print('\n')
print('No. of fraud and no fraud in the training set:')
print(y_train.value_counts())

print('\n')
print('No. fraud and no fraud in the validation set:')
print(y_val.value_counts())
# Out:
# No. of fraud and no fraud in the training set:
# 0    524
# 1    176
# Name: fraud_reported, dtype: int64
#
#
# No. fraud and no fraud in the validation set:
# 0    229
# 1     71
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

from yellowbrick.classifier import ConfusionMatrix
from yellowbrick.classifier import ClassificationReport
from yellowbrick.classifier import ROCAUC

# %%
model = LogisticRegression()

# %%
#The ConfusionMatrix visualizer
classes = ['Non Fraud','Fraud']
cm = ConfusionMatrix(model, classes=classes, percent=False)
cm.fit(X_train, y_train)
cm.score(X_val, y_val)
for label in cm.ax.texts:
    label.set_size(20)
cm.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# <AxesSubplot:title={'center':'LogisticRegression Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
# Instantiate the visualizer
visualizer = ClassificationReport(model, classes=classes)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_val, y_val)  # Evaluate the model on the test data
g = visualizer.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
model.score(X_val, y_val)
# Out:
# 0.76

# %% [markdown]
# # Neural Network MLP Classifier

# %%
from sklearn.neural_network import MLPClassifier

# %%
#declaring MLP classifier model
mlp = MLPClassifier(hidden_layer_sizes=[700,150], verbose=True)

# %%
#training model
mlp.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 19.87558719
# Iteration 2, loss = 9.06249033
# Iteration 3, loss = 11.43107212
# Iteration 4, loss = 18.38234682
# Iteration 5, loss = 9.47441392
# Iteration 6, loss = 12.40939564
# Iteration 7, loss = 12.92430346
# Iteration 8, loss = 16.99109546
# Iteration 9, loss = 9.06248040
# Iteration 10, loss = 17.86742851
# Iteration 11, loss = 11.18139529
# Iteration 12, loss = 12.30640482
# Iteration 13, loss = 11.99750583
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=[700, 150], verbose=True)

# %%
#Model validation 
predictions = mlp.predict(X_val)

# %%
#confusion matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_val,predictions))
# Out:
# [[ 60 169]
#  [ 17  54]]

# %%
#Model accuracy stats
print(classification_report(y_val,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.26      0.39       229
#            1       0.24      0.76      0.37        71
#
#     accuracy                           0.38       300
#    macro avg       0.51      0.51      0.38       300
# weighted avg       0.65      0.38      0.39       300

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtmodel = DecisionTreeClassifier()

# %%
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dtmodel.predict(X_val)

# %%
print(confusion_matrix(y_val,dt_pred))
# Out:
# [[192  37]
#  [ 37  34]]

# %%
print(classification_report(y_val,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84       229
#            1       0.48      0.48      0.48        71
#
#     accuracy                           0.75       300
#    macro avg       0.66      0.66      0.66       300
# weighted avg       0.75      0.75      0.75       300

# %%
# Instantiate the visualizer
visualizer = ClassificationReport(dtmodel, classes=classes)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_val, y_val)  # Evaluate the model on the test data
g = visualizer.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
classes = ['Non Fraud','Fraud']
cm = ConfusionMatrix(dtmodel, classes=classes, percent=False)
cm.fit(X_train, y_train)
cm.score(X_val, y_val)
for label in cm.ax.texts:
    label.set_size(20)
cm.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'DecisionTreeClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
dtmodel.score(X_val, y_val)
# Out:
# 0.7533333333333333

# %%
test_data.columns
# Out:
# Index(['age', 'policy_state', 'policy_deductable', 'policy_annual_premium',
#        'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'capital-gains',
#        'capital-loss', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_year',
#        'fraud_reported'],
#       dtype='object')

# %%
test_data.shape
# Out:
# (1000, 30)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          1000 non-null   int64
#  1   policy_state                 1000 non-null   int32
#  2   policy_deductable            1000 non-null   int64
#  3   policy_annual_premium        1000 non-null   float64
#  4   umbrella_limit               1000 non-null   int64
#  5   insured_zip                  1000 non-null   int64
#  6   insured_sex                  1000 non-null   int64
#  7   insured_education_level      1000 non-null   int32
#  8   insured_occupation           1000 non-null   int32
#  9   capital-gains                1000 non-null   int64
#  10  capital-loss                 1000 non-null   int64
#  11  incident_type                1000 non-null   int32
#  12  collision_type               1000 non-null   int32
# ...

# %%
test_data.head()
# Out:
#    age  policy_state  policy_deductable  policy_annual_premium  \
# 0   48             2               1000                1406.91
# 1   42             1               2000                1197.22
# 2   29             2               2000                1413.14
# 3   41             0               2000                1415.74
# 4   44             0               1000                1583.91
#
#    umbrella_limit  insured_zip  insured_sex  insured_education_level  \
# 0               0       466132            0                        4
# 1         5000000       468176            0                        4
# 2         5000000       430632            1                        6
# 3         6000000       608117            1                        6
# 4         6000000       610706            0                        0
#
#    insured_occupation  capital-gains  capital-loss  incident_type  \
# 0                   2          53300             0              2
# ...

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 1000, random_state = 3)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=3)

# %%
rf_pred= rf.predict(X_val)

# %%
#accuracy score
rf.score(X_val, y_val)*100
# Out:
# 79.66666666666666

# %%
classes = ['Non Fraud','Fraud']
cm = ConfusionMatrix(rf, classes=classes, percent=False)
cm.fit(X_train, y_train)
cm.score(X_val, y_val)
for label in cm.ax.texts:
    label.set_size(20)
cm.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'RandomForestClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
visualizer = ClassificationReport(rf, classes=classes)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_val, y_val)  # Evaluate the model on the test data
g = visualizer.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Gradient Boost Model

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbst = GradientBoostingClassifier(n_estimators=200, learning_rate=2.0, max_depth=1, random_state=3, verbose = True)

# %%
gbst.fit(X_train, y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.1633            1.59s
#          2           2.9751            0.79s
#          3         390.2408            0.52s
#          4         390.2614            0.39s
#          5         390.2386            0.62s
#          6         390.2533            0.52s
#          7         390.2370            0.44s
#          8         390.2481            0.38s
#          9         390.2358            0.34s
#         10         390.2446            0.46s
#         20         390.2366            0.32s
#         30         390.2336            0.29s
#         40         390.2321            0.20s
#         50         390.2312            0.20s
#         60         390.2306            0.20s
#         70         390.2301            0.19s
#         80         390.2298            0.17s
#         90         390.2295            0.14s
#        100         390.2293            0.13s
#        200         390.2284            0.00s
# ...

# %%
gbst_pred= gbst.predict(X_val)

# %%
#Accuracy Score
gbst.score(X_val, y_val)*100
# Out:
# 83.66666666666667

# %%
classes = ['Non Fraud','Fraud']
cm = ConfusionMatrix(gbst, classes=classes, percent=False)
cm.fit(X_train, y_train)
cm.score(X_val, y_val)
for label in cm.ax.texts:
    label.set_size(20)
cm.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'GradientBoostingClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>

# %%
visualizer = ClassificationReport(gbst, classes=classes)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_val, y_val)  # Evaluate the model on the test data
g = visualizer.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc = AdaBoostClassifier(n_estimators=75, learning_rate=2.0, random_state=23)

# %%
abc.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(learning_rate=2.0, n_estimators=75, random_state=23)

# %%
abc_pred= abc.predict(X_val)
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
abc.score(X_val, y_val)*100
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# 83.66666666666667

# %%
classes = ['Non Fraud','Fraud']
cm = ConfusionMatrix(abc, classes=classes, percent=False)
cm.fit(X_train, y_train)
cm.score(X_val, y_val)
for label in cm.ax.texts:
    label.set_size(20)
cm.poof()
# Out:
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\nickm\anaconda3\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'AdaBoostClassifier Confusion Matrix'}, xlabel='Predicted Class', ylabel='True Class'>
